-- %%
select count(*) from 
healthcare_catalog.silver.beneficiary;

select * from 
healthcare_catalog.metadata.silver_watermark;

select * from 
healthcare_catalog.metadata.ingestion_log

-- truncate table healthcare_catalog.silver.beneficiary;

-- delete from  healthcare_catalog.metadata.silver_watermark w
-- where w.source_name='beneficiary'
